# %%
import os
import cv2
import shutil
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

import warnings
warnings.filterwarnings('ignore')

# %%
TRAIN_DIR = '../input/siim-isic-melanoma-classification/jpeg/train'

# %%
train = pd.read_csv('../input/siim-isic-melanoma-classification/train.csv')
train.head()
# Out:
#      image_name  patient_id     sex  age_approx anatom_site_general_challenge  \
# 0  ISIC_2637011  IP_7279968    male        45.0                     head/neck
# 1  ISIC_0015719  IP_3075186  female        45.0               upper extremity
# 2  ISIC_0052212  IP_2842074  female        50.0               lower extremity
# 3  ISIC_0068279  IP_6890425  female        45.0                     head/neck
# 4  ISIC_0074268  IP_8723313  female        55.0               upper extremity
#
#   diagnosis benign_malignant  target
# 0   unknown           benign       0
# 1   unknown           benign       0
# 2     nevus           benign       0
# 3   unknown           benign       0
# 4   unknown           benign       0

# %%
df_train, df_test = train_test_split(train[:3000], test_size=0.2)

# %%
train['target'].value_counts().plot(kind = 'bar', color='blue', title = 'Melanoma distribution' )
# Out:
# <AxesSubplot:title={'center':'Melanoma distribution'}>

# %%
ds_train_mal=df_train.loc[df_train['target']==1]
ds_train_ben=df_train.loc[df_train['target']==0]

ds_train=ds_train_mal.append(ds_train_ben, ignore_index=True)

ds_test_mal=df_test.loc[df_test['target']==1]
ds_test_ben=df_test.loc[df_test['target']==0]

ds_test=ds_test_mal.append(ds_test_ben, ignore_index=True)

weight_for_benign = (1 / len(ds_test_ben)) * (len(ds_train) / 2.0)
weight_for_malignant = (1 / len(ds_test_mal)) * (len(ds_test) / 2.0)

class_weight = {0: weight_for_benign, 1: weight_for_malignant}

print('Weight for class benign: {:.2f}'.format(weight_for_benign))
print('Weight for class malignant: {:.2f}'.format(weight_for_malignant))
# Out:
# Weight for class benign: 2.03
# Weight for class malignant: 37.50

# %%
ds_train['path'] = TRAIN_DIR + "/"+ ds_train.image_name + ".jpg"
ds_test['path'] = TRAIN_DIR + "/"+ ds_test.image_name + ".jpg"
ds_train_images= ds_train[['path', 'target']]
ds_test_images= ds_test[['path', 'target']]

# %%
images = []
labels=[]
# loop over the indexes of the melonoma
for i in range(len(ds_train_images[:1000])):
    image = cv2.imread(ds_train_images.iloc[i,0])
    image = cv2.resize(image, (224, 224))
    images.append(image)
    labels.append(ds_train_images.iloc[i,1])
images = np.array(images) / 255.0

# %%
base_model = tf.keras.applications.ResNet50(input_shape=(224, 224,3), include_top=False, weights='imagenet')
model = tf.keras.models.Sequential()
model.add(base_model)
model.add(tf.keras.layers.GlobalAveragePooling2D())
model.add(tf.keras.layers.Dense(1024, activation='relu'))
model.add(tf.keras.layers.Dense(1, activation='sigmoid'))

# %%
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
history = model.fit(x=np.array(images), y=np.array(labels),
                    steps_per_epoch=100, 
                    epochs=50,
                    class_weight=class_weight,
)
# Out:
# Epoch 1/50
# 100/100 [==============================] - 234s 2s/step - loss: 5.9241 - accuracy: 0.9030
# Epoch 2/50
# 100/100 [==============================] - 233s 2s/step - loss: 4.0095 - accuracy: 0.5800
# Epoch 3/50
# 100/100 [==============================] - 225s 2s/step - loss: 2.2242 - accuracy: 0.5570
# Epoch 4/50
# 100/100 [==============================] - 228s 2s/step - loss: 3.2338 - accuracy: 0.5430
# Epoch 5/50
# 100/100 [==============================] - 227s 2s/step - loss: 2.3642 - accuracy: 0.6210
# Epoch 6/50
# 100/100 [==============================] - 225s 2s/step - loss: 2.5555 - accuracy: 0.8630
# Epoch 7/50
# 100/100 [==============================] - 231s 2s/step - loss: 1.9527 - accuracy: 0.7580
# Epoch 8/50
# 100/100 [==============================] - 227s 2s/step - loss: 1.7622 - accuracy: 0.7190
# Epoch 9/50
# 100/100 [==============================] - 228s 2s/step - loss: 1.7858 - accuracy: 0.6810
# Epoch 10/50
# 100/100 [==============================] - 234s 2s/step - loss: 1.8622 - accuracy: 0.6670
# Epoch 11/50
# 100/100 [==============================] - 226s 2s/step - loss: 2.8615 - accuracy: 0.7180
# Epoch 12/50
# 100/100 [==============================] - 227s 2s/step - loss: 1.9075 - accuracy: 0.7460
# Epoch 13/50
# 100/100 [==============================] - 229s 2s/step - loss: 1.8361 - accuracy: 0.7240
# Epoch 14/50
# 100/100 [==============================] - 224s 2s/step - loss: 1.7664 - accuracy: 0.6970
# Epoch 15/50
# 100/100 [==============================] - 229s 2s/step - loss: 1.9404 - accuracy: 0.7450
# Epoch 16/50
# 100/100 [==============================] - 226s 2s/step - loss: 2.1510 - accuracy: 0.7830
# Epoch 17/50
# 100/100 [==============================] - 228s 2s/step - loss: 1.9511 - accuracy: 0.7280
# Epoch 18/50
# 100/100 [==============================] - 235s 2s/step - loss: 1.7952 - accuracy: 0.7670
# Epoch 19/50
# 100/100 [==============================] - 228s 2s/step - loss: 1.9738 - accuracy: 0.7420
# Epoch 20/50
# 100/100 [==============================] - 235s 2s/step - loss: 1.7789 - accuracy: 0.7580
# Epoch 21/50
# 100/100 [==============================] - 235s 2s/step - loss: 2.5537 - accuracy: 0.7790
# Epoch 22/50
# 100/100 [==============================] - 230s 2s/step - loss: 2.4408 - accuracy: 0.7140
# Epoch 23/50
# 100/100 [==============================] - 238s 2s/step - loss: 2.1407 - accuracy: 0.7030
# Epoch 24/50
# 100/100 [==============================] - 229s 2s/step - loss: 1.9950 - accuracy: 0.7160
# Epoch 25/50
# 100/100 [==============================] - 230s 2s/step - loss: 2.1372 - accuracy: 0.7850
# Epoch 26/50
# 100/100 [==============================] - 244s 2s/step - loss: 2.1428 - accuracy: 0.6560
# Epoch 27/50
# 100/100 [==============================] - 230s 2s/step - loss: 1.8849 - accuracy: 0.7810
# Epoch 28/50
# 100/100 [==============================] - 235s 2s/step - loss: 1.8110 - accuracy: 0.7280
# Epoch 29/50
# 100/100 [==============================] - 228s 2s/step - loss: 1.8874 - accuracy: 0.7390
# Epoch 30/50
# 100/100 [==============================] - 232s 2s/step - loss: 2.0503 - accuracy: 0.7100
# Epoch 31/50
# 100/100 [==============================] - 233s 2s/step - loss: 1.8115 - accuracy: 0.7110
# Epoch 32/50
# 100/100 [==============================] - 225s 2s/step - loss: 1.7442 - accuracy: 0.7390
# Epoch 33/50
# 100/100 [==============================] - 231s 2s/step - loss: 1.7589 - accuracy: 0.7440
# Epoch 34/50
# 100/100 [==============================] - 227s 2s/step - loss: 1.9242 - accuracy: 0.7110
# Epoch 35/50
# 100/100 [==============================] - 230s 2s/step - loss: 1.7740 - accuracy: 0.7230
# Epoch 36/50
# 100/100 [==============================] - 230s 2s/step - loss: 1.7303 - accuracy: 0.7250
# Epoch 37/50
# 100/100 [==============================] - 229s 2s/step - loss: 1.8479 - accuracy: 0.7300
# Epoch 38/50
# 100/100 [==============================] - 234s 2s/step - loss: 1.8386 - accuracy: 0.6980
# Epoch 39/50
# 100/100 [==============================] - 229s 2s/step - loss: 1.7552 - accuracy: 0.6860
# Epoch 40/50
# 100/100 [==============================] - 228s 2s/step - loss: 1.7259 - accuracy: 0.6750
# Epoch 41/50
# 100/100 [==============================] - 229s 2s/step - loss: 1.9441 - accuracy: 0.7860
# Epoch 42/50
# 100/100 [==============================] - 229s 2s/step - loss: 2.0181 - accuracy: 0.6340
# Epoch 43/50
# 100/100 [==============================] - 230s 2s/step - loss: 1.9885 - accuracy: 0.7460
# Epoch 44/50
# 100/100 [==============================] - 230s 2s/step - loss: 1.8299 - accuracy: 0.6710
# Epoch 45/50
# 100/100 [==============================] - 232s 2s/step - loss: 1.8639 - accuracy: 0.7140
# Epoch 46/50
# 100/100 [==============================] - 235s 2s/step - loss: 2.0276 - accuracy: 0.7090
# Epoch 47/50
# 100/100 [==============================] - 231s 2s/step - loss: 1.7520 - accuracy: 0.6480
# Epoch 48/50
# 100/100 [==============================] - 235s 2s/step - loss: 1.7476 - accuracy: 0.7540
# Epoch 49/50
# 100/100 [==============================] - 230s 2s/step - loss: 1.8976 - accuracy: 0.6740
# Epoch 50/50
# 100/100 [==============================] - 233s 2s/step - loss: 1.9205 - accuracy: 0.6820

# %%
model.save('./imageModel.h5')

# %%
train_dataset=ds_train[['age_approx',  'sex', 'anatom_site_general_challenge','diagnosis', 'target']]
#Converting to onehot vector
sex_dummies = pd.get_dummies(train_dataset['sex'], prefix='sex')
train_dataset = pd.concat([train_dataset, sex_dummies], axis=1)
anatom_dummies = pd.get_dummies(train_dataset['anatom_site_general_challenge'], prefix='anatom')
train_dataset = pd.concat([train_dataset, anatom_dummies], axis=1)
diag_dummies = pd.get_dummies(train_dataset['diagnosis'], prefix='diagnosis')
train_dataset = pd.concat([train_dataset, diag_dummies], axis=1)
train_dataset_y= train_dataset['target']
train_dataset.drop(['target'], axis=1, inplace=True)
train_dataset.head(2)
# Out:
#    age_approx     sex anatom_site_general_challenge diagnosis  sex_female  \
# 0        45.0    male                         torso  melanoma           0
# 1        75.0  female                     head/neck  melanoma           1
#
#    sex_male  anatom_head/neck  anatom_lower extremity  anatom_oral/genital  \
# 0         1                 0                       0                    0
# 1         0                 1                       0                    0
#
#    anatom_palms/soles  anatom_torso  anatom_upper extremity  \
# 0                   0             1                       0
# 1                   0             0                       0
#
#    diagnosis_lentigo NOS  diagnosis_lichenoid keratosis  diagnosis_melanoma  \
# 0                      0                              0                   1
# 1                      0                              0                   1
#
#    diagnosis_nevus  diagnosis_seborrheic keratosis  diagnosis_unknown
# 0                0                               0                  0
# 1                0                               0                  0

# %%
model_ann = tf.keras.Sequential()
model_ann.add(tf.keras.layers.Dense(32, input_dim=15, activation='relu'))
model_ann.add(tf.keras.layers.Dense(12, activation='relu'))
model_ann.add(tf.keras.layers.Dense(1, activation='sigmoid'))

# %%
train_dataset.drop(columns = ['sex', 'anatom_site_general_challenge', 'diagnosis'], inplace =True)

# %%
model_ann.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
history_tab = model_ann.fit(train_dataset, train_dataset_y, epochs=10, batch_size=64, class_weight=class_weight)
# Out:
# Epoch 1/10
# 38/38 [==============================] - 1s 4ms/step - loss: 3.4659 - accuracy: 0.7208
# Epoch 2/10
# 38/38 [==============================] - 0s 2ms/step - loss: 1.7085 - accuracy: 0.9850
# Epoch 3/10
# 38/38 [==============================] - 0s 2ms/step - loss: 1.6675 - accuracy: 0.9850
# Epoch 4/10
# 38/38 [==============================] - 0s 2ms/step - loss: 1.6280 - accuracy: 0.9850
# Epoch 5/10
# 38/38 [==============================] - 0s 2ms/step - loss: 1.5916 - accuracy: 0.9850
# Epoch 6/10
# 38/38 [==============================] - 0s 2ms/step - loss: 1.5592 - accuracy: 0.9850
# Epoch 7/10
# 38/38 [==============================] - 0s 2ms/step - loss: 1.5296 - accuracy: 0.9850
# Epoch 8/10
# 38/38 [==============================] - 0s 2ms/step - loss: 1.5039 - accuracy: 0.9850
# Epoch 9/10
# 38/38 [==============================] - 0s 2ms/step - loss: 1.4806 - accuracy: 0.9850
# Epoch 10/10
# 38/38 [==============================] - 0s 2ms/step - loss: 1.4610 - accuracy: 0.9850

# %%
model_ann.save('./modelText.h5')

# %%
num_output_layers=1
concate = tf.keras.layers.concatenate([model.layers[-1].output, model_ann.layers[-1].output])
output_1=tf.keras.layers.Dense(units=num_output_layers, activation="sigmoid", name="num_01_output")(concate)
concate_model= tf.keras.Model(inputs=[model.input, model_ann.input], outputs=output_1)

# %%
tf.keras.utils.plot_model(concate_model, 'model.png',show_shapes=True,show_layer_names=True)

# %%
for layer in concate_model.layers[:-1]:
  layer.trainable = False

# %%
concate_model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
history_concatenate= concate_model.fit(x=[np.array(images),np.array(train_dataset)[:1000]],
                                       y=np.array(train_dataset_y)[:1000], epochs=50, class_weight=class_weight                                     
)
# Out:
# Epoch 1/50
# 32/32 [==============================] - 63s 2s/step - loss: 2.5327 - accuracy: 0.0360
# Epoch 2/50
# 32/32 [==============================] - 58s 2s/step - loss: 2.4965 - accuracy: 0.0360
# Epoch 3/50
# 32/32 [==============================] - 58s 2s/step - loss: 2.4673 - accuracy: 0.0360
# Epoch 4/50
# 32/32 [==============================] - 59s 2s/step - loss: 2.4404 - accuracy: 0.0360
# Epoch 5/50
# 32/32 [==============================] - 59s 2s/step - loss: 2.4154 - accuracy: 0.0360
# Epoch 6/50
# 32/32 [==============================] - 58s 2s/step - loss: 2.3933 - accuracy: 0.0360
# Epoch 7/50
# 32/32 [==============================] - 59s 2s/step - loss: 2.3714 - accuracy: 0.0360
# Epoch 8/50
# 32/32 [==============================] - 61s 2s/step - loss: 2.3541 - accuracy: 0.0360
# Epoch 9/50
# 32/32 [==============================] - 61s 2s/step - loss: 2.3384 - accuracy: 0.0360
# Epoch 10/50
# 32/32 [==============================] - 61s 2s/step - loss: 2.3242 - accuracy: 0.0360
# Epoch 11/50
# 32/32 [==============================] - 61s 2s/step - loss: 2.3116 - accuracy: 0.0360
# Epoch 12/50
# 32/32 [==============================] - 60s 2s/step - loss: 2.3034 - accuracy: 0.0360
# Epoch 13/50
# 32/32 [==============================] - 59s 2s/step - loss: 2.2938 - accuracy: 0.2420
# Epoch 14/50
# 32/32 [==============================] - 59s 2s/step - loss: 2.2862 - accuracy: 0.7530
# Epoch 15/50
# 32/32 [==============================] - 59s 2s/step - loss: 2.2782 - accuracy: 0.9600
# Epoch 16/50
# 32/32 [==============================] - 59s 2s/step - loss: 2.2715 - accuracy: 0.9640
# Epoch 17/50
# 32/32 [==============================] - 59s 2s/step - loss: 2.2654 - accuracy: 0.9640
# Epoch 18/50
# 32/32 [==============================] - 59s 2s/step - loss: 2.2601 - accuracy: 0.9640
# Epoch 19/50
# 32/32 [==============================] - 60s 2s/step - loss: 2.2554 - accuracy: 0.9640
# Epoch 20/50
# 32/32 [==============================] - 60s 2s/step - loss: 2.2517 - accuracy: 0.9640
# Epoch 21/50
# 32/32 [==============================] - 59s 2s/step - loss: 2.2489 - accuracy: 0.9640
# Epoch 22/50
# 32/32 [==============================] - 59s 2s/step - loss: 2.2462 - accuracy: 0.9640
# Epoch 23/50
# 32/32 [==============================] - 59s 2s/step - loss: 2.2436 - accuracy: 0.9640
# Epoch 24/50
# 32/32 [==============================] - 59s 2s/step - loss: 2.2416 - accuracy: 0.9640
# Epoch 25/50
# 32/32 [==============================] - 59s 2s/step - loss: 2.2400 - accuracy: 0.9640
# Epoch 26/50
# 32/32 [==============================] - 58s 2s/step - loss: 2.2382 - accuracy: 0.9640
# Epoch 27/50
# 32/32 [==============================] - 59s 2s/step - loss: 2.2366 - accuracy: 0.9640
# Epoch 28/50
# 32/32 [==============================] - 59s 2s/step - loss: 2.2357 - accuracy: 0.9640
# Epoch 29/50
# 32/32 [==============================] - 59s 2s/step - loss: 2.2344 - accuracy: 0.9640
# Epoch 30/50
# 32/32 [==============================] - 60s 2s/step - loss: 2.2338 - accuracy: 0.9640
# Epoch 31/50
# 32/32 [==============================] - 59s 2s/step - loss: 2.2333 - accuracy: 0.9640
# Epoch 32/50
# 32/32 [==============================] - 59s 2s/step - loss: 2.2330 - accuracy: 0.9640
# Epoch 33/50
# 32/32 [==============================] - 58s 2s/step - loss: 2.2321 - accuracy: 0.9640
# Epoch 34/50
# 32/32 [==============================] - 58s 2s/step - loss: 2.2317 - accuracy: 0.9640
# Epoch 35/50
# 32/32 [==============================] - 58s 2s/step - loss: 2.2313 - accuracy: 0.9640
# Epoch 36/50
# 32/32 [==============================] - 59s 2s/step - loss: 2.2312 - accuracy: 0.9640
# Epoch 37/50
# 32/32 [==============================] - 58s 2s/step - loss: 2.2306 - accuracy: 0.9640
# Epoch 38/50
# 32/32 [==============================] - 59s 2s/step - loss: 2.2306 - accuracy: 0.9640
# Epoch 39/50
# 32/32 [==============================] - 59s 2s/step - loss: 2.2302 - accuracy: 0.9640
# Epoch 40/50
# 32/32 [==============================] - 59s 2s/step - loss: 2.2301 - accuracy: 0.9640
# Epoch 41/50
# 32/32 [==============================] - 60s 2s/step - loss: 2.2298 - accuracy: 0.9640
# Epoch 42/50
# 32/32 [==============================] - 60s 2s/step - loss: 2.2298 - accuracy: 0.9640
# Epoch 43/50
# 32/32 [==============================] - 59s 2s/step - loss: 2.2295 - accuracy: 0.9640
# Epoch 44/50
# 32/32 [==============================] - 59s 2s/step - loss: 2.2291 - accuracy: 0.9640
# Epoch 45/50
# 32/32 [==============================] - 58s 2s/step - loss: 2.2292 - accuracy: 0.9640
# Epoch 46/50
# 32/32 [==============================] - 60s 2s/step - loss: 2.2291 - accuracy: 0.9640
# Epoch 47/50
# 32/32 [==============================] - 59s 2s/step - loss: 2.2289 - accuracy: 0.9640
# Epoch 48/50
# 32/32 [==============================] - 59s 2s/step - loss: 2.2289 - accuracy: 0.9640
# Epoch 49/50
# 32/32 [==============================] - 59s 2s/step - loss: 2.2288 - accuracy: 0.9640
# Epoch 50/50
# 32/32 [==============================] - 61s 2s/step - loss: 2.2291 - accuracy: 0.9640

# %%
concate_model.save('./imagesTextCombined.h5')
